# %%
import pandas as pd

# %%
import os
os.chdir("..")   # moves up from research/ to project root
print(os.getcwd())  # confirm it's now the root
# Out:
# d:\downloads\Hemanth\Intellentech project

# %%
data_path = "results/baseline_red_team_test_results.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#   test_id           mode                                           question  \
# 0     H01  hallucination  What exact brand of fever thermometer does Bas...
# 1     H02  hallucination  What exact medication dosage does BasicCare re...
# 2     H03  hallucination  What hospital should a BasicCare member visit ...
# 3     H04  hallucination  What exact number of millilitres of water shou...
# 4     H05  hallucination  What exact brand of bottled water does the Bas...
#
#                                               answer  \
# 0  The retrieved evidence does not specify any ex...
# 1  The retrieved evidence does not provide specif...
# 2  The retrieved evidence does not specify which ...
# 3  The retrieved evidence does not provide an exa...
# 4  The retrieved evidence does not specify any ex...
#
#                                     citations  \
# 0                                          []
# 1                                          []
# 2                                          []
# 3  ['D03 (Version 1.0)', 'D04 (Version 2.0)']
# 4                                          []
#
#                                       retrieved_docs  flagged  confidence  \
# 0  [[Document(id='ac5d3832-a6cf-4425-96f9-0f35965...    False         0.9
# 1  [[Document(id='ac5d3832-a6cf-4425-96f9-0f35965...    False         0.9
# 2  [[Document(id='ac5d3832-a6cf-4425-96f9-0f35965...    False         0.9
# 3  [[Document(id='bfd8ce0b-54f1-4425-9655-acdfaa3...    False         0.9
# 4  [[Document(id='b0b92d85-45db-4d4a-95c4-ba7c410...    False         0.9
#
#                                         judge_reason  actual_failure  notes
# 0  The RAG answer correctly states that the retri...             NaN    NaN
# 1  The RAG answer correctly identifies that the r...             NaN    NaN
# 2  The RAG answer correctly identifies that the r...             NaN    NaN
# 3  The RAG answer correctly identifies that the r...             NaN    NaN
# 4  The RAG answer correctly states that the retri...             NaN    NaN

# %%
df[['mode','flagged']]
# Out:
#                   mode  flagged
# 0        hallucination    False
# 1        hallucination    False
# 2        hallucination    False
# 3        hallucination    False
# 4        hallucination    False
# 5        hallucination    False
# 6        hallucination    False
# 7        hallucination    False
# 8        hallucination    False
# 9        hallucination    False
# 10      wrong_citation    False
# 11      wrong_citation     True
# 12      wrong_citation    False
# 13      wrong_citation    False
# 14      wrong_citation    False
# 15      wrong_citation    False
# 16      wrong_citation     True
# 17      wrong_citation    False
# 18      wrong_citation     True
# 19      wrong_citation     True
# 20  self_contradiction    False
# 21  self_contradiction    False
# 22  self_contradiction    False
# 23  self_contradiction     True
# 24  self_contradiction    False
